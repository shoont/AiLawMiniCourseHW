# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of
# WARNING:tensorflow:From <ipython-input-5-bad51c6b3b41>:177: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Initialized
# Average loss at step  0 :  275.867553711
# Nearest to i: circumcising, mawson, cretans, shusui, think, infantryman, enthalpy, anyone,
# Nearest to been: surprising, protege, tara, correctly, penalties, motherboards, creation, parrots,
# Nearest to after: technicality, epinephrine, microchips, synchronicity, lyell, clocking, duffy, fuzes,
# Nearest to see: ultrasonic, inquired, converse, keating, pierson, hyperinflation, shipping, twentieth,
# Nearest to than: jts, altaic, pri, aristocratic, motions, may, autocorrelation, shopping,
# Nearest to or: kamehameha, endows, bottomed, fuses, angled, sulfate, haw, linearly,
# Nearest to during: sifra, sequencer, antiques, termination, lecture, sublimation, ortho, comedienne,
# Nearest to so: psychosis, spice, catahoula, arcadia, bulbs, insecure, esc, hydrate,
# Nearest to b: refinements, inefficient, url, magnesians, salvage, conner, braking, dinosaurs,
# Nearest to and: lfflin, hexafluoride, rhyme, parisians, mumia, bravery, textiles, paschal,
# Nearest to of: favourites, mayhew, discussion, debating, oppressed, hearted, ef, oem,
# Nearest to will: dachshund, sanskaras, smiley, fraenkel, accused, jon, parental, forbids,
# Nearest to these: breakfast, gottorp, reworked, stab, overcoming, stevenson, spoke, unep,
# Nearest to his: greifswald, schaefer, parliaments, defective, suspended, dividing, contrasted, tsr,
# Nearest to which: proto, favorable, khattab, jfk, globular, girolamo, lesser, transition,
# Nearest to UNK: assertion, decks, inhibitor, trax, gere, perpetrators, secular, facilitates,
# Average loss at step  2000 :  114.438568714
# Average loss at step  4000 :  52.4553127496
# Average loss at step  6000 :  33.3290855813
# Average loss at step  8000 :  23.18469857
# Average loss at step  10000 :  17.9619224944
# Nearest to i: phi, pages, manufacturing, anyone, think, profound, hector, advanced,
# Nearest to been: correctly, phi, format, captain, creation, create, surprising, penalties,
# Nearest to after: instructs, carry, major, yield, bckgr, animals, throughout, and,
# Nearest to see: six, nine, twentieth, shipping, may, dependent, bckgr, promotes,
# Nearest to than: shopping, altaic, convincingly, experimentation, for, yeast, may, gimme,
# Nearest to or: and, UNK, from, gland, boards, sura, richard, in,
# Nearest to during: basins, our, review, front, drag, sequencer, mixture, previous,
# Nearest to so: aberdeenshire, archie, pronunciation, humans, legal, hydrate, material, audiences,
# Nearest to b: camus, and, gland, altenberg, subsequent, liberty, invited, course,
# Nearest to and: in, of, UNK, gland, or, boards, to, a,
# Nearest to of: and, in, for, with, the, bckgr, gland, at,
# Nearest to will: ungodly, kbit, describe, confirmation, fraenkel, billboard, choice, bad,
# Nearest to these: overcoming, state, spoke, many, roper, dhabi, inevitably, trucks,
# Nearest to his: the, a, their, parliaments, and, million, defective, s,
# Nearest to which: lesser, tournament, proto, archive, transition, favorable, antimatter, aurora,
# Nearest to UNK: one, and, vs, the, fao, phi, mathbf, boards,
# Average loss at step  12000 :  14.0814689837
# Average loss at step  14000 :  11.542618742
# Average loss at step  16000 :  10.0257206116
# Average loss at step  18000 :  8.46234309959
# Average loss at step  20000 :  7.91678886855
# Nearest to i: UNK, circ, phi, foster, anyone, tolkien, think, mawson,
# Nearest to been: by, sargon, dinah, be, phi, was, correctly, captain,
# Nearest to after: technicality, and, carry, instructs, major, for, dasyprocta, agouti,
# Nearest to see: gollancz, progressively, six, shipping, is, keating, devastated, zero,
# Nearest to than: for, shopping, or, convincingly, agouti, garlic, experimentation, motions,
# Nearest to or: and, UNK, dasyprocta, circ, the, agouti, three, from,
# Nearest to during: from, yankovic, of, by, three, our, with, review,
# Nearest to so: bulbs, aberdeenshire, apr, merlin, serpent, archie, y, pronunciation,
# Nearest to b: d, and, circ, in, one, rudolph, dinosaurs, inefficient,
# Nearest to and: in, or, dasyprocta, of, operatorname, agouti, gland, circ,
# Nearest to of: and, in, for, nine, agouti, eight, gland, from,
# Nearest to will: fricative, ungodly, forbids, billboard, maid, fraenkel, to, jon,
# Nearest to these: the, many, overcoming, state, justices, pelagius, circ, nlm,
# Nearest to his: their, the, s, a, iota, dasyprocta, circ, its,
# Nearest to which: that, this, and, lesser, dasyprocta, but, it, favorable,
# Nearest to UNK: agouti, circ, dasyprocta, operatorname, phi, three, epistles, two,
# Average loss at step  22000 :  6.9727961303
# Average loss at step  24000 :  6.82665929914
# Average loss at step  26000 :  6.67587269092
# Average loss at step  28000 :  6.39222166038
# Average loss at step  30000 :  5.97239810002
# Nearest to i: foster, circ, phi, ii, manufacturing, flashback, think, anyone,
# Nearest to been: by, be, sargon, was, also, dinah, sped, had,
# Nearest to after: technicality, and, instructs, major, fuzes, carry, for, in,
# Nearest to see: progressively, is, shipping, gollancz, sponsors, zero, twentieth, six,
# Nearest to than: for, or, birkenau, jts, convincingly, motions, shopping, and,
# Nearest to or: and, dasyprocta, circ, UNK, agouti, six, operatorname, gland,
# Nearest to during: from, with, by, in, but, yankovic, six, of,
# Nearest to so: varphi, psychosis, birkenau, bulbs, apr, primigenius, aberdeenshire, pronunciation,
# Nearest to b: d, and, circ, rudolph, inefficient, dinosaurs, one, targets,
# Nearest to and: or, dasyprocta, agouti, in, circ, operatorname, six, one,
# Nearest to of: and, in, for, agouti, eight, nine, with, abet,
# Nearest to will: would, forbids, ungodly, to, can, maid, fricative, sponsor,
# Nearest to these: many, justices, some, circ, all, dasyprocta, state, pelagius,
# Nearest to his: their, the, its, s, her, theism, iota, dasyprocta,
# Nearest to which: that, this, it, birkenau, tonnage, and, but, dasyprocta,
# Nearest to UNK: circ, agouti, dasyprocta, operatorname, amalthea, four, five, two,
# Average loss at step  32000 :  5.99078869247
# Average loss at step  34000 :  5.71285281408
# Average loss at step  36000 :  5.78102883554
# Average loss at step  38000 :  5.53331974387
# Average loss at step  40000 :  5.22814724004
# Nearest to i: ii, foster, you, circ, UNK, phi, flashback, we,
# Nearest to been: be, by, was, had, also, sped, sargon, dinah,
# Nearest to after: major, technicality, albury, instructs, fuzes, in, dasyprocta, for,
# Nearest to see: progressively, zero, shipping, gollancz, is, sponsors, twentieth, devastated,
# Nearest to than: or, birkenau, for, jts, motions, convincingly, garlic, abbreviations,
# Nearest to or: and, dasyprocta, circ, zero, gland, agouti, six, operatorname,
# Nearest to during: from, with, by, in, at, but, of, throughout,
# Nearest to so: psychosis, bulbs, varphi, birkenau, apr, aberdeenshire, almost, serpent,
# Nearest to b: d, circ, rudolph, inefficient, eight, and, four, UNK,
# Nearest to and: or, dasyprocta, in, but, zero, operatorname, agouti, circ,
# Nearest to of: albury, in, and, zero, agouti, for, nine, gland,
# Nearest to will: would, can, to, forbids, ungodly, maid, sponsor, fraenkel,
# Nearest to these: many, some, all, justices, programmable, which, dasyprocta, circ,
# Nearest to his: their, the, its, her, theism, s, dasyprocta, circ,
# Nearest to which: that, this, it, but, tonnage, birkenau, and, dasyprocta,
# Nearest to UNK: agouti, circ, dasyprocta, albury, four, operatorname, three, phi,
# Average loss at step  42000 :  5.37614233446
# Average loss at step  44000 :  5.25890528762
# Average loss at step  46000 :  5.22732023823
# Average loss at step  48000 :  5.2081052047
# Average loss at step  50000 :  4.97818995214
# Nearest to i: you, ii, foster, circ, phi, we, flashback, pages,
# Nearest to been: be, was, also, by, franchisee, had, sped, sargon,
# Nearest to after: major, technicality, albury, before, instructs, for, while, dasyprocta,
# Nearest to see: progressively, shipping, and, is, can, sponsors, gollancz, nsw,
# Nearest to than: or, for, and, birkenau, agouti, gigantopithecus, jts, motions,
# Nearest to or: and, dasyprocta, six, gland, kapoor, circ, four, agouti,
# Nearest to during: in, from, by, but, at, with, throughout, of,
# Nearest to so: psychosis, almost, bulbs, apr, birkenau, varphi, serpent, aberdeenshire,
# Nearest to b: d, circ, rudolph, inefficient, kapoor, and, eight, one,
# Nearest to and: or, six, but, kapoor, dasyprocta, four, eight, operatorname,
# Nearest to of: in, for, agouti, albury, kapoor, eight, s, operatorname,
# Nearest to will: would, can, to, ungodly, forbids, maid, and, could,
# Nearest to these: many, some, all, justices, such, the, two, programmable,
# Nearest to his: their, the, its, her, s, theism, dasyprocta, circ,
# Nearest to which: that, this, it, but, one, also, birkenau, and,
# Nearest to UNK: kapoor, dasyprocta, agouti, albury, circ, operatorname, amalthea, five,
# Average loss at step  52000 :  5.0502019133
# Average loss at step  54000 :  5.18983337402
# Average loss at step  56000 :  5.03095466042
# Average loss at step  58000 :  5.05908624935
# Average loss at step  60000 :  4.93978813851
# Nearest to i: you, ii, foster, circ, we, michelob, phi, flashback,
# Nearest to been: be, was, by, had, franchisee, sargon, dinah, sped,
# Nearest to after: before, when, while, albury, technicality, major, six, instructs,
# Nearest to see: progressively, shipping, and, can, devastated, is, nsw, twentieth,
# Nearest to than: or, for, birkenau, and, agouti, abet, pulau, motions,
# Nearest to or: and, pulau, ursus, dasyprocta, six, gland, kapoor, agouti,
# Nearest to during: in, from, at, by, but, throughout, with, six,
# Nearest to so: pulau, almost, ursus, birkenau, albury, bulbs, psychosis, varphi,
# Nearest to b: d, circ, inefficient, rudolph, UNK, raions, depriving, kapoor,
# Nearest to and: or, but, pulau, dasyprocta, ursus, kapoor, in, agouti,
# Nearest to of: and, ursus, in, for, albury, michelob, agouti, kapoor,
# Nearest to will: would, can, to, could, may, ungodly, forbids, maid,
# Nearest to these: many, some, all, such, justices, two, pulau, several,
# Nearest to his: their, her, its, the, s, dasyprocta, albury, theism,
# Nearest to which: that, this, it, but, also, one, birkenau, dasyprocta,
# Nearest to UNK: kapoor, agouti, dasyprocta, ursus, circ, albury, michelob, operatorname,
# Average loss at step  62000 :  5.04208163917
# Average loss at step  64000 :  4.83199689692
# Average loss at step  66000 :  4.59189485455
# Average loss at step  68000 :  4.98590472913
# Average loss at step  70000 :  4.88898807085
# Nearest to i: you, ii, foster, we, circ, michelob, UNK, seven,
# Nearest to been: be, was, had, franchisee, by, were, also, sped,
# Nearest to after: before, when, while, albury, during, technicality, for, instructs,
# Nearest to see: progressively, can, shipping, devastated, microcebus, is, nsw, twentieth,
# Nearest to than: or, much, birkenau, for, pulau, agouti, motions, abet,
# Nearest to or: and, ursus, dasyprocta, but, pulau, gland, microcebus, kapoor,
# Nearest to during: in, from, at, by, after, throughout, but, with,
# Nearest to so: pulau, birkenau, bulbs, albury, ursus, psychosis, almost, pronunciation,
# Nearest to b: d, UNK, circ, microcebus, seven, rudolph, mico, upanija,
# Nearest to and: or, dasyprocta, but, pulau, ursus, kapoor, microcebus, agouti,
# Nearest to of: ursus, michelob, agouti, and, kapoor, albury, operatorname, andamanese,
# Nearest to will: would, can, may, could, to, forbids, ungodly, michelob,
# Nearest to these: many, some, all, such, several, cebus, justices, which,
# Nearest to his: their, her, its, the, thaler, s, rupiah, cebus,
# Nearest to which: that, this, it, but, also, tonnage, birkenau, dasyprocta,
# Nearest to UNK: kapoor, agouti, ursus, dasyprocta, microcebus, thaler, circ, operatorname,
# Average loss at step  72000 :  4.75925536859
# Average loss at step  74000 :  4.80213559747
# Average loss at step  76000 :  4.71936103415
# Average loss at step  78000 :  4.80751864433
# Average loss at step  80000 :  4.79641986418
# Nearest to i: you, ii, UNK, circ, foster, we, michelob, seven,
# Nearest to been: be, was, had, franchisee, were, become, by, sargon,
# Nearest to after: before, when, while, during, technicality, albury, for, oiled,
# Nearest to see: progressively, shipping, can, devastated, microcebus, nsw, escapement, michelob,
# Nearest to than: or, much, birkenau, for, pulau, agouti, abet, gigantopithecus,
# Nearest to or: and, dasyprocta, ursus, fachhochschule, kapoor, gland, pulau, but,
# Nearest to during: in, from, by, after, throughout, but, at, through,
# Nearest to so: pulau, albury, birkenau, almost, ursus, bulbs, psychosis, sometimes,
# Nearest to b: d, UNK, circ, microcebus, mico, rudolph, kapoor, upanija,
# Nearest to and: or, but, pulau, kapoor, operatorname, dasyprocta, ursus, upanija,
# Nearest to of: ursus, agouti, kapoor, michelob, albury, operatorname, in, abet,
# Nearest to will: would, can, may, could, to, forbids, ungodly, sponsor,
# Nearest to these: many, some, such, all, several, cebus, which, both,
# Nearest to his: their, her, its, the, s, thz, thaler, greifswald,
# Nearest to which: that, this, it, also, one, but, tonnage, dasyprocta,
# Nearest to UNK: kapoor, ursus, dasyprocta, agouti, microcebus, thaler, circ, albury,
# Average loss at step  82000 :  4.75909608734
# Average loss at step  84000 :  4.75585481727
# Average loss at step  86000 :  4.78271996474
# Average loss at step  88000 :  4.7464967078
# Average loss at step  90000 :  4.73596964335
# Nearest to i: you, ii, we, foster, circ, UNK, they, tolkien,
# Nearest to been: be, was, had, become, franchisee, were, dinah, by,
# Nearest to after: before, when, while, during, albury, without, technicality, from,
# Nearest to see: progressively, can, shipping, escapement, devastated, and, attribution, microcebus,
# Nearest to than: or, much, for, birkenau, shabda, agouti, pulau, havilland,
# Nearest to or: and, dasyprocta, ursus, kapoor, fachhochschule, pulau, but, six,
# Nearest to during: in, after, from, throughout, by, but, at, with,
# Nearest to so: pulau, albury, birkenau, ursus, psychosis, varphi, almost, sometimes,
# Nearest to b: d, UNK, circ, microcebus, mico, rudolph, four, kapoor,
# Nearest to and: or, but, pulau, ursus, dasyprocta, operatorname, upanija, kapoor,
# Nearest to of: ursus, in, michelob, same, agouti, operatorname, andamanese, and,
# Nearest to will: would, can, may, could, to, should, does, must,
# Nearest to these: many, some, such, all, several, which, both, cebus,
# Nearest to his: their, her, its, the, s, our, thz, greifswald,
# Nearest to which: that, this, it, but, also, tonnage, birkenau, dasyprocta,
# Nearest to UNK: kapoor, agouti, ursus, microcebus, dasyprocta, circ, michelob, thaler,
# Average loss at step  92000 :  4.66934254396
# Average loss at step  94000 :  4.71730828977
# Average loss at step  96000 :  4.69528155911
# Average loss at step  98000 :  4.58089841902
# Average loss at step  100000 :  4.68194267702
# Nearest to i: you, ii, we, foster, circ, they, UNK, tolkien,
# Nearest to been: be, was, become, had, franchisee, dinah, by, were,
# Nearest to after: before, when, during, while, albury, without, in, technicality,
# Nearest to see: progressively, can, michelob, shipping, microcebus, escapement, ursus, devastated,
# Nearest to than: or, much, birkenau, shabda, agouti, for, havilland, abet,
# Nearest to or: and, ursus, dasyprocta, kapoor, gland, fachhochschule, but, than,
# Nearest to during: in, after, throughout, from, at, before, by, with,
# Nearest to so: pulau, albury, birkenau, sometimes, ursus, almost, varphi, bulbs,
# Nearest to b: d, circ, microcebus, mico, rudolph, upanija, thaler, kapoor,
# Nearest to and: or, but, ursus, pulau, constituci, dasyprocta, kapoor, operatorname,
# Nearest to of: ursus, albury, agouti, kapoor, michelob, including, abet, and,
# Nearest to will: would, can, may, could, to, must, should, does,
# Nearest to these: many, some, such, several, all, both, which, their,
# Nearest to his: their, her, its, the, s, our, rupiah, thz,
# Nearest to which: that, this, but, it, also, dasyprocta, and, tonnage,
# Nearest to UNK: kapoor, ursus, agouti, thaler, dasyprocta, circ, albury, microcebus,
